# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.2.2
# # *Mining Social Media with Twitter*

# %% [markdown]
# ## The Twitter API and Tweepy Package

# %% [markdown]
# The Twitter API provides access to tweets and comments, and allows an application to post tweets to the user's timeline.
#
# Twitter requires developers to create and authenticate an app before they can use the API. As of recent policy changes, however, new developers must be approved before they can create an app. There is no indication of the waiting period for approval.

# %% [markdown]
# ### 1. Apply for Developer Access
#
# Go to https://blog.twitter.com/developer/en_us/topics/tools/2018/new-developer-requirements-to-protect-our-platform.html
# and read the advice.

# %% [markdown]
# Apply at https://developer.twitter.com/en/apply-for-access.html. Where asked state that you will use the app as a student to explore the tweepy Python library and use it to fetch recent tweets and to create/delete a tweet.

# %% [markdown]
# ### 2. Create Your Twitter App
# Go to https://developer.twitter.com/en/portal/projects-and-apps and click on the "+ Create App" button. Give your app a name and then you will be able to generate Consumer Keys (API key & secret) and Authentication Tokens (Access token & secret). Copy-paste these authentication details for use in this lab.

# %% [markdown]
# ### 3. Load Python Libraries

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/36/1b/2bd38043d22ade352fc3d3902cf30ce0e2f4bf285be3b304a2782a767aec/tweepy-3.8.0-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.11.1 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: PySocks>=1.5.7 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from tweepy) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from requests>=2.11.1->tweepy) (1.24.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/ahmedfattah/anaconda3/anaconda3/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Installing collected packages: tweepy
# Successfully installed tweepy-3.8.0

# %%
import tweepy
import json
import pprint

# %% [markdown]
# ### 4. Authenticate from your Python script

# %% [markdown]
# You could assign your authentication details explicitly, as follows:

# %%
my_consumer_key = 'GS7kRxkpveBFqpey6myCwJ01d'      # your consumer key (string) goes in here
my_consumer_secret = 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'   # your consumer secret key (string) goes in here
my_access_token = '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr'      # your access token (string) goes in here
access_token_secret = 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW'  # your access token secret (string) goes in here

# %%
import json

auth_twitter_json = {
    'consumer_key': 'GS7kRxkpveBFqpey6myCwJ01d'      # your consumer key (string) goes in here
    , 'consumer_secret': 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'   # your consumer secret key (string) goes in here
    , 'access_token': '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr'      # your access token (string goes in here
    , 'access_token_secret': 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW'  # your access token secret (string) goes in here
}

with open('auth_twitter.json', 'w') as outfile:  
    json.dump(auth_twitter_json, outfile)

# %% [markdown]
# A better way would be to store these details externally, so they are not displayed in the notebook:
#
# - create a file called "auth_twitter.json" in your "notebooks" directory, and save your credentials there in JSON format:
#
# `{`<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`   "consumer_key": "your consumer key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;` "consumer_secret": "your consumer secret key (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"access_token": "your access token (string) goes in here",` <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"access_token_secret": "your access token secret (string) goes in here"` <br>
# `}`
#
# (Nb. Parsers are very fussy. Make sure each key:value pair has a comma after it except the last one!)
#
# Use the following code to load the credentials:

# %%
pwd()  # make sure your working directory is where the file is
# Out:
# 'C:\\Users\\Mai Anh\\Documents\\IOD\\Course Content - v 1.1\\Module 2\\Labs 2\\Lab Answers'

# %%
path_auth = 'auth_twitter.json'
auth = json.loads(open(path_auth).read())
pp = pprint.PrettyPrinter(indent=4)
# For debugging only:
pp.pprint(auth)
# Out:
# {   'access_token': '82147042-L7wiMqxZqib6XiLdpphwskaKGKfEjZfMw4mhEdMOr',
#     'access_token_secret': 'EZvfP55xXAmqymu3SpDL8yxVKVOe9DFYYFwfiaBbMWckW',
#     'consumer_key': 'GS7kRxkpveBFqpey6myCwJ01d',
#     'consumer_secret': 'gGc9bnCGYQvjDY8M47foKmRSdl6FuFqmOIAOIJMn4M39rIlXUT'}

# %%
my_consumer_key = auth['consumer_key']
my_consumer_secret = auth['consumer_secret']
my_access_token = auth['access_token']
my_access_token_secret = auth['access_token_secret']

# %% [markdown]
# Security considerations:
# - this method only keeps your credentials invisible as long as nobody accesses this notebook while it's running on your computer
# - if you wanted another user to have access to the executable notebook without divulging your credentials you should set up an OAuth 2.0 workflow to let them obtain and apply their own API tokens when using your app
# - if you just want to share your analyses, you could use a separate script (which you don't share) to fetch the data and save it locally, then use a second notebook (with no API access) to load and analyse the locally stored data

# %% [markdown]
# ### 5. Exploring the API

# %% [markdown]
# Here is how to connect to Twitter using the Tweepy library:

# %%
auth = tweepy.OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# In the next cell, put the cursor after the '.' and hit the [tab] key to see the available members and methods in the response object:

# %%
api.followers()[0]._json
# Out:
# {'id': 1169320255375781888,
#  'id_str': '1169320255375781888',
#  'name': 'Abdυlra7mαn 🌐',
#  'screen_name': 'Abdulra7man_M_H',
#  'location': '',
#  'description': '#Freelance_Translator (En🔄Ar) |                          \n#Logo_Designer 🎨 | #Video_Editor 🎞 | ve Türk dilini seviyorum',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 206,
#  'friends_count': 1897,
#  'listed_count': 0,
#  'created_at': 'Wed Sep 04 18:44:27 +0000 2019',
#  'favourites_count': 350,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 149,
#  'lang': None,
#  'status': {'created_at': 'Mon Jun 01 00:58:26 +0000 2020',
#   'id': 1267259174687301632,
#   'id_str': '1267259174687301632',
#   'text': '#مكتشف_علاج\nمن عجائب زمن #كورونا أن يظهر بين حين وآخر اسم جديد لمكتشف علاج همشته الحكومات، بينما يرتكز تقدم العلم ا… https://t.co/Is42HMmTzT',
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'مكتشف_علاج', 'indices': [0, 11]},
#     {'text': 'كورونا', 'indices': [25, 32]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Is42HMmTzT',
#      'expanded_url': 'https://twitter.com/i/web/status/1267259174687301632',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'ar'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1207782982116708352/8T9iuL_a_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1207782982116708352/8T9iuL_a_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1169320255375781888/1590015922',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'live_following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'muting': False,
#  'blocking': False,
#  'blocked_by': False,
#  'translator_type': 'none'}

# %% [markdown]
# Consult the Tweept and Twitter API documentation. Print a few of the response members below:

# %%
# Retrieve a Twitter user object
obama = api.get_user('barackobama')

# %%
obama.status
# Out:
# Status(_api=<tweepy.api.API object at 0x000002B06D723A88>, _json={'created_at': 'Fri May 29 16:06:54 +0000 2020', 'id': 1266400635429310466, 'id_str': '1266400635429310466', 'text': 'My statement on the death of George Floyd: https://t.co/Hg1k9JHT6R', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1266400446517829633, 'id_str': '1266400446517829633', 'indices': [43, 66], 'media_url': 'http://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'url': 'https://t.co/Hg1k9JHT6R', 'display_url': 'pic.twitter.com/Hg1k9JHT6R', 'expanded_url': 'https://twitter.com/BarackObama/status/1266400635429310466/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1098, 'resize': 'fit'}, 'small': {'w': 680, 'h': 622, 'resize': 'fit'}, 'large': {'w': 1226, 'h': 1122, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1266400446517829633, 'id_str': '1266400446517829633', 'indices': [43, 66], 'media_url': 'http://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'url': 'https://t.co/Hg1k9JHT6R', 'display_url': 'pic.twitter.com/Hg1k9JHT6R', 'expanded_url': 'https://twitter.com/BarackObama/status/1266400635429310466/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1098, 'resize': 'fit'}, 'small': {'w': 680, 'h': 622, 'resize': 'fit'}, 'large': {'w': 1226, 'h': 1122, 'resize': 'fit'}}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 473126, 'favorite_count': 1890053, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 5, 29, 16, 6, 54), id=1266400635429310466, id_str='1266400635429310466', text='My statement on the death of George Floyd: https://t.co/Hg1k9JHT6R', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1266400446517829633, 'id_str': '1266400446517829633', 'indices': [43, 66], 'media_url': 'http://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'url': 'https://t.co/Hg1k9JHT6R', 'display_url': 'pic.twitter.com/Hg1k9JHT6R', 'expanded_url': 'https://twitter.com/BarackObama/status/1266400635429310466/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1098, 'resize': 'fit'}, 'small': {'w': 680, 'h': 622, 'resize': 'fit'}, 'large': {'w': 1226, 'h': 1122, 'resize': 'fit'}}}]}, extended_entities={'media': [{'id': 1266400446517829633, 'id_str': '1266400446517829633', 'indices': [43, 66], 'media_url': 'http://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EZMofxYXYAELmWd.jpg', 'url': 'https://t.co/Hg1k9JHT6R', 'display_url': 'pic.twitter.com/Hg1k9JHT6R', 'expanded_url': 'https://twitter.com/BarackObama/status/1266400635429310466/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 1098, 'resize': 'fit'}, 'small': {'w': 680, 'h': 622, 'resize': 'fit'}, 'large': {'w': 1226, 'h': 1122, 'resize': 'fit'}}}]}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, geo=None, coordinates=None, place=None, contributors=None, is_quote_status=False, retweet_count=473126, favorite_count=1890053, favorited=False, retweeted=False, possib ...

# %% [markdown]
# This will fetch recent tweets from accounts you follow:

# %%
# Recent tweets from accounts you follow:
tweets = api.home_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# RT @ACABNATlON: PERRY THE PLATYPUS IS A BASTARD https://t.co/KRXrbMVELT
# RT @cricmash: 1 June 2002 Hansie Cronje crashes to his death
# by @senantix
#
# #cricket #onthisday #death
#
# https://t.co/uxUpuZUtps
# 1 June 2002 Hansie Cronje crashes to his death
# #cricket #onthisday
#
# https://t.co/dcgnjoHrZ4
# This morning's @EveningStandard #protests2020 #BlackLivesMatter #GeorgeFloyd #Christo #cartoon https://t.co/1MB2U8C5X1
# *Ding ding* In the blue corner... @brendan_pang! #MasterChefAU https://t.co/uEAGAvX8vK
# RT @cricmash: 1 June 1887 When batsmen threw their wickets away because there was no concept of declaration
# by @ovshake42
#
# #cricket #onth…
# andyzing: 2x 20KG Adjustable Dumbbell/Barbell $85.40 + Shipping @ Dshop https://t.co/RfYOhhmepe
# On this day: Born June 2, 1980: Abby Wambach, American soccer player https://t.co/bVuCl4zSiZ https://t.co/es03j2L1GG
# Pristine Solar: [VIC] 6.6kW Jinko 370W Solar Panels + 5kW Fronius Inverter Fully Installed from $3,511 ($1,623 Upfr… https://t.co/2k6fdMNHkJ
# bobby33: $20 off When Spend over $100 https://t.co/hhsRVXbZW7
# That biriyani scene early on in Kaithi.. that is now my NO 1 FAVOURITE scene in a Tamil movie.
#
# The play of emotio… https://t.co/qAcnvQ167Z
# Will they spray sanitiser at trophy presentations in the future? - The Briefing
#
# https://t.co/syPjHQfBRD
# Orange you glad you joined us this evening? 😍🍊 #MasterChefAU https://t.co/GuqPvAYRno
# I am honoured to be named National Goodwill Ambassador for @WFP, the @UN agency that fights hunger worldwide, inclu… https://t.co/1Ungl37GWW
# Move over, R-Patz: how Timothée Chalamet became the movie star of his generation https://t.co/UU27u75hvt
# RT @D_Melissa2: @MayneReport @crikey_news @rupertmurdoch @realDonaldTrump Absolutely!!!! - love 💓 @TurnbullMalcolm ‘s voice - courageous an…
# RT @RohitBhargava7: Excited to be going live tomorrow morning with @TurnbullMalcolm for Ep114 of @PlaybookStartup. We will be talking about…
# Happy birthday my fidgety little brother @DineshKarthik ... you are one of the nicest, warmest people I know. Love… https://t.co/Uz0CvzSX5p
# Time to play with Mario's Snakes 💪 https://t.co/ZM0EKRz8tp

# %% [markdown]
# The request to see your own recent tweets is similar, but uses the `user_timeline` endpoint. Try this below:

# %%
#ANSWER:
# Your recent tweets:
tweets = api.user_timeline()
for tweet in tweets:
    print(tweet.text)
# Out:
# Best! #LotrReunion https://t.co/UERxUXQiY6
# @robelinda2 No wonder he skips tour in sub-continent.
# @ovshake42 @realDonaldTrump 😂
# Until today IELTS was the most useless exam I passed. Now it's SCRUM Master Certified. #ScrumStudy #TimeWaste
# কোন এক সময় যদি ফিজি অস্ট্রেলিয়ার অংশ হয়ে যায়, তখন কী ফিজির চাঁদ দেখে সিডনিতে ঈদ করা যাবে?
# সিডনি থেকে ফিজির দূরত্ব ~৩০০০ কিমি। সিডনি থেকে পার্থের দূরত্ব ~৪০০০ কিমি। পার্থে চাঁদ দেখলে চাঁদ দেখা কমিটি সিডনিতে… https://t.co/YNsa7KhWVB
# @moonsightingau https://t.co/cqGge8pKXs
# @ovshake42 @shoaib100mph usually talks shit. This is no different.
# Best!
#
# https://t.co/pAD1nIvvL6
# RT @thedancingbogan: @LiebCricket Facts...Waugh was Australia’s greatest ever captain, he lead the greatest Australian cricket ever, Warne…
# RT @cricketingview: Kohli shouldn't have got past Shakib-Al-Hasan. Kohli's just an average T20 bat. Shakib is an average bat and bowler in…
# @BarrettSeller https://t.co/EZrLeGNGYi
# Sweaters. Hero.
#
# #RishiKapoor
# RT @TheAcademy: A mainstay of Bollywood cinema and incredible talent in films like “Slumdog Millionaire,” “Life of Pi” and “The Namesake,”…
# RT @nytimes: Irrfan Khan, an Indian film star who brought a modern sensibility to recent hit movies and was featured in several Hollywood f…
# : Will you remember this day?
#
# : How long do I have to remember it?
#
# : Try to remember it always. Remember that you… https://t.co/O7pCP2p92u
# @mufaddal_vohra Did he play with Kohli?
# #MustRead https://t.co/MW6riWZxW7
# @Adil_baloch_ @robelinda2 https://t.co/itPTquN3Vf
# The West Wing (1-4)
# Parks &amp; Recreation (2-7)
# Better Call Saul
# Breaking Bad
# Coupling
# Mind Your Language
# Sherlock (1-… https://t.co/Q1A5QABXM6

# %% [markdown]
# Now, instead of printing the text of each tweet, print the `created_at` and `id_str` methods:

# %%
#ANSWER:
# tweets header info
tweets = api.user_timeline()
for tweet in tweets:
    print(tweet.created_at)
#     print(tweet.id_str)
    print(tweet.text)
# Out:
# 2020-06-01 06:59:40
# Best! #LotrReunion https://t.co/UERxUXQiY6
# 2020-05-31 09:06:06
# @robelinda2 No wonder he skips tour in sub-continent.
# 2020-05-29 13:27:01
# @ovshake42 @realDonaldTrump 😂
# 2020-05-28 23:34:24
# Until today IELTS was the most useless exam I passed. Now it's SCRUM Master Certified. #ScrumStudy #TimeWaste
# 2020-05-23 13:43:00
# কোন এক সময় যদি ফিজি অস্ট্রেলিয়ার অংশ হয়ে যায়, তখন কী ফিজির চাঁদ দেখে সিডনিতে ঈদ করা যাবে?
# 2020-05-23 13:43:00
# সিডনি থেকে ফিজির দূরত্ব ~৩০০০ কিমি। সিডনি থেকে পার্থের দূরত্ব ~৪০০০ কিমি। পার্থে চাঁদ দেখলে চাঁদ দেখা কমিটি সিডনিতে… https://t.co/YNsa7KhWVB
# 2020-05-23 08:23:10
# @moonsightingau https://t.co/cqGge8pKXs
# 2020-05-19 12:15:50
# @ovshake42 @shoaib100mph usually talks shit. This is no different.
# 2020-05-19 09:37:57
# Best!
#
# https://t.co/pAD1nIvvL6
# 2020-05-17 08:55:03
# RT @thedancingbogan: @LiebCricket Facts...Waugh was Australia’s greatest ever captain, he lead the greatest Australian cricket ever, Warne…
# 2020-05-03 05:22:15
# RT @cricketingview: Kohli shouldn't have got past Shakib-Al-Hasan. Kohli's just an average T20 bat. Shakib is an average bat and bowler in…
# 2020-05-02 12:31:50
# @BarrettSeller https://t.co/EZrLeGNGYi
# 2020-04-30 05:54:45
# Sweaters. Hero.
#
# #RishiKapoor
# 2020-04-29 16:25:41
# RT @TheAcademy: A mainstay of Bollywood cinema and incredible talent in films like “Slumdog Millionaire,” “Life of Pi” and “The Namesake,”…
# 2020-04-29 11:39:12
# RT @nytimes: Irrfan Khan, an Indian film star who brought a modern sensibility to recent hit movies and was featured in several Hollywood f…
# 2020-04-29 09:47:38
# : Will you remember this day?
#
# : How long do I have to remember it?
#
# : Try to remember it always. Remember that you… https://t.co/O7pCP2p92u
# 2020-04-29 09:42:04
# @mufaddal_vohra Did he play with Kohli?
# 2020-04-27 11:57:17
# #MustRead https://t.co/MW6riWZxW7
# 2020-04-27 01:51:39
# @Adil_baloch_ @robelinda2 https://t.co/itPTquN3Vf
# 2020-04-26 00:24:42
# The West Wing (1-4)
# Parks &amp; Recreation (2-7)
# Better Call Saul
# Breaking Bad
# Coupling
# Mind Your Language
# Sherlock (1-… https://t.co/Q1A5QABXM6

# %%
tweet_list = []
for tweet in tweets:
    tweet_list.append(tweet._json)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(tweet_list)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df.set_index('created_at', inplace=True)

# %%
df.head()
# Out:
#                                             id               id_str  \
# created_at
# 2020-06-01 06:59:40+00:00  1267350083416109056  1267350083416109056
# 2020-05-31 09:06:06+00:00  1267019511921704960  1267019511921704960
# 2020-05-29 13:27:01+00:00  1266360398711648262  1266360398711648262
# 2020-05-28 23:34:24+00:00  1266150864235855872  1266150864235855872
# 2020-05-23 13:43:00+00:00  1264190093473878028  1264190093473878028
#
#                                                                         text  \
# created_at
# 2020-06-01 06:59:40+00:00         Best! #LotrReunion https://t.co/UERxUXQiY6
# 2020-05-31 09:06:06+00:00  @robelinda2 No wonder he skips tour in sub-con...
# 2020-05-29 13:27:01+00:00                      @ovshake42 @realDonaldTrump 😂
# 2020-05-28 23:34:24+00:00  Until today IELTS was the most useless exam I ...
# 2020-05-23 13:43:00+00:00  কোন এক সময় যদি ফিজি অস্ট্রেলিয়ার অংশ হয়ে যা...
#
#                            truncated  \
# created_at
# 2020-06-01 06:59:40+00:00      False
# 2020-05-31 09:06:06+00:00      False
# 2020-05-29 13:27:01+00:00      False
# 2020-05-28 23:34:24+00:00      False
# 2020-05-23 13:43:00+00:00      False
#
#                                                                     entities  \
# created_at
# 2020-06-01 06:59:40+00:00  {'hashtags': [{'text': 'LotrReunion', 'indices...
# 2020-05-31 09:06:06+00:00  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2020-05-29 13:27:01+00:00  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2020-05-28 23:34:24+00:00  {'hashtags': [{'text': 'ScrumStudy', 'indices'...
# 2020-05-23 13:43:00+00:00  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                                            extended_entities  \
# created_at
# 2020-06-01 06:59:40+00:00  {'media': [{'id': 1267350076579393537, 'id_str...
# 2020-05-31 09:06:06+00:00                                                NaN
# 2020-05-29 13:27:01+00:00                                                NaN
# 2020-05-28 23:34:24+00:00                                                NaN
# 2020-05-23 13:43:00+00:00                                                NaN
#
#                                                                       source  \
# created_at
# 2020-06-01 06:59:40+00:00  <a href="http://twitter.com/download/android" ...
# 2020-05-31 09:06:06+00:00  <a href="http://twitter.com/download/android" ...
# 2020-05-29 13:27:01+00:00  <a href="http://twitter.com/download/android" ...
# 2020-05-28 23:34:24+00:00  <a href="http://twitter.com/download/android" ...
# 2020-05-23 13:43:00+00:00  <a href="http://twitter.com/download/android" ...
#
#                            in_reply_to_status_id in_reply_to_status_id_str  \
# created_at
# 2020-06-01 06:59:40+00:00                    NaN                      None
# 2020-05-31 09:06:06+00:00           1.266900e+18       1266900189274443776
# 2020-05-29 13:27:01+00:00           1.266360e+18       1266360053092675584
# 2020-05-28 23:34:24+00:00                    NaN                      None
# 2020-05-23 13:43:00+00:00           1.264190e+18       1264190092052058112
#
#                            in_reply_to_user_id  ... retweet_count  \
# created_at                                      ...
# 2020-06-01 06:59:40+00:00                  NaN  ...             0
# 2020-05-31 09:06:06+00:00           35399625.0  ...             0
# 2020-05-29 13:27:01+00:00          541499063.0  ...             0
# 2020-05-28 23:34:24+00:00                  NaN  ...             0
# 2020-05-23 13:43:00+00:00           82147042.0  ...             0
#
#                           favorite_count favorited retweeted  \
# created_at
# 2020-06-01 06:59:40+00:00              0     False     False
# 2020-05-31 09:06:06+00:00              0     False     False
# 2020-05-29 13:27:01+00:00              0     False     False
# 2020-05-28 23:34:24+00:00              0     False     False
# 2020-05-23 13:43:00+00:00              0     False     False
#
#                           possibly_sensitive lang retweeted_status  \
# created_at
# 2020-06-01 06:59:40+00:00              False   en              NaN
# 2020-05-31 09:06:06+00:00                NaN   en              NaN
# 2020-05-29 13:27:01+00:00                NaN  und              NaN
# 2020-05-28 23:34:24+00:00                NaN   en              NaN
# 2020-05-23 13:43:00+00:00                NaN   bn              NaN
#
#                            quoted_status_id  quoted_status_id_str  \
# created_at
# 2020-06-01 06:59:40+00:00               NaN                   NaN
# 2020-05-31 09:06:06+00:00               NaN                   NaN
# 2020-05-29 13:27:01+00:00               NaN                   NaN
# 2020-05-28 23:34:24+00:00               NaN                   NaN
# 2020-05-23 13:43:00+00:00               NaN                   NaN
#
#                            quoted_status
# created_at
# 2020-06-01 06:59:40+00:00            NaN
# 2020-05-31 09:06:06+00:00            NaN
# 2020-05-29 13:27:01+00:00            NaN
# 2020-05-28 23:34:24+00:00            NaN
# 2020-05-23 13:43:00+00:00            NaN
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                             int64
# id_str                        object
# text                          object
# truncated                       bool
# entities                      object
# extended_entities             object
# source                        object
# in_reply_to_status_id        float64
# in_reply_to_status_id_str     object
# in_reply_to_user_id          float64
# in_reply_to_user_id_str       object
# in_reply_to_screen_name       object
# user                          object
# geo                           object
# coordinates                   object
# place                         object
# contributors                  object
# is_quote_status                 bool
# retweet_count                  int64
# favorite_count                 int64
# favorited                       bool
# retweeted                       bool
# possibly_sensitive            object
# lang                          object
# retweeted_status              object
# quoted_status_id             float64
# quoted_status_id_str          object
# quoted_status                 object
# dtype: object

# %%
y = df['id'].resample('D').sum()
y.plot(figsize=(15, 6));

# %%
from wordcloud import WordCloud, STOPWORDS
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-09aeca815748> in <module>
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
def check_tweets(twitter_handle):
    json_str = []
    for status in tweepy.Cursor(api.user_timeline,id=twitter_handle).items(200):
        json_str.append(status._json)
    
    df = pd.DataFrame(json_str)
    df['created_at'] = pd.to_datetime(df['created_at'])
    df.set_index('created_at', inplace=True)
    
    y = df['id'].resample('D').count()
    y.plot(figsize=(15, 6))
    plt.show();

# %%
def check_tweets_wordcloud(twitter_handle, withall=True):
    json_str = []
    for status in tweepy.Cursor(api.user_timeline,id=twitter_handle).items(200):
        json_str.append(status._json)
    
    df = pd.DataFrame(json_str)
    
    if withall: 
        text = df.text.values
    else:
        text = ','.join([x for x in df.text.values])
        blob = TextBlob(text)
        text = blob.noun_phrases
    
    wordcloud = WordCloud(
        width = 3000
        , height = 2000
        , background_color = 'black'
        , stopwords = STOPWORDS
    ).generate(str(text))
    
    fig = plt.figure(figsize = (40, 30), facecolor = 'k', edgecolor = 'k')
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.show();

# %%
check_tweets('realDonaldTrump')

# %%
check_tweets_wordcloud('realDonaldTrump', withall=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-74ef9b1c9041> in <module>
# ----> 1 check_tweets_wordcloud('realDonaldTrump', withall=False)
#
# <ipython-input-21-41b54f5af5e2> in check_tweets_wordcloud(twitter_handle, withall)
#      10     else:
#      11         text = ','.join([x for x in df.text.values])
# ---> 12         blob = TextBlob(text)
#      13         text = blob.noun_phrases
#      14
#
# NameError: name 'TextBlob' is not defined

# %% [markdown]
# You can create a tweet as follows:

# %%
# create a tweet:
tweet = api.update_status('Test: Made with Tweepy')

# %% [markdown]
# (Nb. Don't abuse this feature! If you try to generate a zillion tweets in a loop, Twitter will ban youur account.)

# %% [markdown]
# Tweets can be deleted by reference to their `id_str` attribute:

# %%
# delete a tweet:
status = api.destroy_status(tweet.id_str)

# %% [markdown]
# You can follow a Tweeter:

# %%
# follow:
api.create_friendship('@YouTube')
# Out:
# User(_api=<tweepy.api.API object at 0x10d27fd50>, _json={'id': 10228272, 'id_str': '10228272', 'name': 'YouTube at 🏠', 'screen_name': 'YouTube', 'location': 'San Bruno, CA', 'description': 'Stay Home #WithMe', 'url': 'https://t.co/qkVaJFk2CG', 'entities': {'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 72431914, 'friends_count': 1085, 'listed_count': 82132, 'created_at': 'Tue Nov 13 21:43:46 +0000 2007', 'favourites_count': 3136, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 25346, 'lang': None, 'status': {'created_at': 'Mon Apr 20 05:44:01 +0000 2020', 'id': 1252110754259406848, 'id_str': '1252110754259406848', 'text': "Start your week with this 'Perfect' kalimba cover by Vietnamese creator Trúc Ly → https://t.co/eRDPRHIiTC https://t.co/B9mnvPeM5p", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/eRDPRHIiTC', 'expanded_url': 'https://yt.be/zVDJ', 'display_url': 'yt.be/zVDJ', 'indices': [82, 105]}], 'media': [{'id': 1252110528287105024, 'id_str': '1252110528287105024', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'url': 'https://t.co/B9mnvPeM5p', 'display_url': 'pic.twitter.com/B9mnvPeM5p', 'expanded_url': 'https://twitter.com/YouTube/status/1252110754259406848/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1252110528287105024, 'id_str': '1252110528287105024', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'url': 'https://t.co/B9mnvPeM5p', 'display_url': 'pic.twitter.com/B9mnvPeM5p', 'expanded_url': 'https://twitter.com/YouTube/status/1252110754259406848/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [1, 1], 'duration_millis': 15508, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/pl/9oE8thFKoqm3etYO.m3u8?tag=10'}, {'bitrate': 1280000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/720x720/7eGAX0Skna1N94wp.mp4?tag=10'}, {'bitrate': 432000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/320x320/k_4HhNKXVbtF0dhW.mp4?tag=10'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/480x480/iPk5wXkfy7D8fa7M.mp4?tag=10'}]}, 'additional_media_info': {'monetizable': False}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 354, 'favorite_count': 1626, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'AF0000', 'profile_background_image_url':  ...

# %% [markdown]
# or unfollow:

# %%
# unfollow:
api.destroy_friendship('@YouTube')
# Out:
# User(_api=<tweepy.api.API object at 0x10d27fd50>, _json={'id': 10228272, 'id_str': '10228272', 'name': 'YouTube at 🏠', 'screen_name': 'YouTube', 'location': 'San Bruno, CA', 'description': 'Stay Home #WithMe', 'url': 'https://t.co/qkVaJFk2CG', 'entities': {'url': {'urls': [{'url': 'https://t.co/qkVaJFk2CG', 'expanded_url': 'https://www.youtube.com/', 'display_url': 'youtube.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 72431913, 'friends_count': 1085, 'listed_count': 82132, 'created_at': 'Tue Nov 13 21:43:46 +0000 2007', 'favourites_count': 3136, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 25346, 'lang': None, 'status': {'created_at': 'Mon Apr 20 05:44:01 +0000 2020', 'id': 1252110754259406848, 'id_str': '1252110754259406848', 'text': "Start your week with this 'Perfect' kalimba cover by Vietnamese creator Trúc Ly → https://t.co/eRDPRHIiTC https://t.co/B9mnvPeM5p", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/eRDPRHIiTC', 'expanded_url': 'https://yt.be/zVDJ', 'display_url': 'yt.be/zVDJ', 'indices': [82, 105]}], 'media': [{'id': 1252110528287105024, 'id_str': '1252110528287105024', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'url': 'https://t.co/B9mnvPeM5p', 'display_url': 'pic.twitter.com/B9mnvPeM5p', 'expanded_url': 'https://twitter.com/YouTube/status/1252110754259406848/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1252110528287105024, 'id_str': '1252110528287105024', 'indices': [106, 129], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1252110528287105024/pu/img/gtalEVJET8R30WMk.jpg', 'url': 'https://t.co/B9mnvPeM5p', 'display_url': 'pic.twitter.com/B9mnvPeM5p', 'expanded_url': 'https://twitter.com/YouTube/status/1252110754259406848/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'video_info': {'aspect_ratio': [1, 1], 'duration_millis': 15508, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/pl/9oE8thFKoqm3etYO.m3u8?tag=10'}, {'bitrate': 1280000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/720x720/7eGAX0Skna1N94wp.mp4?tag=10'}, {'bitrate': 432000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/320x320/k_4HhNKXVbtF0dhW.mp4?tag=10'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/ext_tw_video/1252110528287105024/pu/vid/480x480/iPk5wXkfy7D8fa7M.mp4?tag=10'}]}, 'additional_media_info': {'monetizable': False}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 354, 'favorite_count': 1626, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': 'AF0000', 'profile_background_image_url':  ...

# %% [markdown]
# >
# >
# >
# >
# >

# %% [markdown]
# >
# >

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
