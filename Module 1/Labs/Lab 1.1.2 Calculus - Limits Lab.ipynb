# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Limits

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function, say f(x) = 1/x
def f(x):
    return 1/x

# %%
# calculate value of f(x) for some values
print('f(4) = ',f(4))
# Out:
# f(4) =  0.25

# %%
# calculate value of f(x) for 0, not possible as there will be Zero Division Error
# print('f(0) = ', f(0))

# %% [markdown]
# Plot y versus x as lines and/or markers.
#
# > matplotlib.pyplot.plot
#
# [matplotlib.pyplot.plot](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# plot f(x) from a small number to a large number
x = np.arange(0.1,100,1)
y = f(x)
# Specify the graph Figure Size
plt.figure(figsize = (14, 7))
plt.plot(x,y)
# Always Label Your Axis!
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# Plot f(x) from a small number to a large number with logarithmic scale.
#
# > Hint: plt.yscale('log')

# %%
# plot f(x) from a small number to a large number with logarithmic scale
x = np.arange(0.1,100,1)
y = f(x)

# Specify the graph Figure Size
plt.figure(figsize = (14, 7))
# Plot the graph and remember to label your Axis
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.yscale('log') # Use 'log' to change the scale of f(x) to a logarithmic scale 
plt.grid()
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
