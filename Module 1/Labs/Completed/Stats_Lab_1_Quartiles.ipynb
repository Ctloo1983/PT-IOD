# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Sample Input
STDIN                   Function
-----                   --------    
9                       arr[] size n = 9 
3 7 8 5 12 14 21 13 18  arr = [3, 7, 8, 5, 12, 14, 21, 13,18]

# Sample output
6
12
16

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'quartiles' function below.
#
# The function is expected to return an INTEGER_ARRAY.
# The function accepts INTEGER_ARRAY arr as parameter.
#

# Input array
input = 3 7 8 5 12 14

#Length of array 
n_input = ???

def quartiles(input):
    data = list(map(int, input.rstrip().split()))
    n = int(strip(len(data))
    # Write your code here

# %%
# Test cases

# Come up with test cases which look at different combinations of arrays. 
# A good starting point is the array [0], just to check if the code works.
# Then try inputs with different lengths (even + odd) to see how the results change
# The goal is to check how robust the code is, and whether it works in all scenarios
