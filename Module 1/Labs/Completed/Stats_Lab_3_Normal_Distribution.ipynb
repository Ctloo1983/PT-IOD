# %% [markdown]
# # Tutorial

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Questions

# %% [markdown]
# ## Q1
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q2
# ![image.png](data:image/png;base64,...)
