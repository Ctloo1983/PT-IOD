# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
# Load libraries and modules.....  eg. 'stats' is a module from scipy library!
# Examples of libraries are numpy, pandas, matplotlib.pyplot and scipy etc, etc...
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# get matplot to show charts inline
# %matplotlib inline

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
# from google.colab import files
# uploaded = files.upload()
# import io
# df = pd.read_csv(io.BytesIO(uploaded["Employee-attrition.csv"]))
df = pd.read_csv("Employee-attrition.csv")

# %%
# Load first 5 rows of dataset
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Load last 5 rows of dataset
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
# columns = df.columns
# index = df.index
# data = df.values

# %%
# view column names
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# List column names
df.columns.to_list()
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'DailyRate',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'Over18',
#  'OverTime',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
# check column index start stop and step
df.index
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %%
df.values
# Out:
# array([[41, 'Yes', 'Travel_Rarely', ..., 4, 0, 5],
#        [49, 'No', 'Travel_Frequently', ..., 7, 1, 7],
#        [37, 'Yes', 'Travel_Rarely', ..., 0, 0, 0],
#        ...,
#        [27, 'No', 'Travel_Rarely', ..., 2, 0, 3],
#        [49, 'No', 'Travel_Frequently', ..., 6, 0, 8],
#        [34, 'No', 'Travel_Rarely', ..., 3, 1, 2]], dtype=object)

# %%
# Code for getting a list of the unique values inside a column or feature named 'Gender'
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
# The describe method only takes in numeric columns (int and floats)
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A: 
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %%
# Code for getting the value counts of categorical and numerical columns
df.dtypes.value_counts()
# Out:
# int64     26
# object     9
# dtype: int64

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
# This code is a summary of the column dtypes and the non-null count of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A: Rename the column JobRole to Job_Title!
df['JobRole']

df.rename(columns={'JobRole': 'Job_Title'}, inplace=True)

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A: Use value_counts() method
job_title = df['Job_Title']
job_title.value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: Job_Title, dtype: int64

# %%
# Check the Change in name of JobRole to Job_Title the dataframe, can use .T to see the columns easier
df.head().T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                             Yes                      No
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %%
# Create Function to Row_Count
def row_count(column_name):
    number_of_rows = len(df[column_name])
    number_of_unique_rows = df[column_name].value_counts()
    return number_of_rows, number_of_unique_rows

print(row_count('Job_Title'))
# Out:
# (1470, Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: Job_Title, dtype: int64)

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A: NB : ALWAYS MAKE SURE YOU SPELL EVERYTHING CORRECT!
age = df['Age']
age.describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A: Tedious Method:
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 60

# %%
df['Age'].mean()
# Out:
# 36.923809523809524

# %%
df['Age'].std()
# Out:
# 9.135373489136734

# %%
# This is the shortcut method!
df['Age'].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:
df.set_index('EmployeeNumber', inplace=True)

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
# print('df.loc["1318"]', df.loc[8188])
# print(df.loc[8188])

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df.sort_index()
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1                41       Yes      Travel_Rarely       1102
# 2                49        No  Travel_Frequently        279
# 4                37       Yes      Travel_Rarely       1373
# 5                33        No  Travel_Frequently       1392
# 7                27        No      Travel_Rarely        591
# ...             ...       ...                ...        ...
# 2061             36        No  Travel_Frequently        884
# 2062             39        No      Travel_Rarely        613
# 2064             27        No      Travel_Rarely        155
# 2065             49        No  Travel_Frequently       1023
# 2068             34        No      Travel_Rarely        628
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1                                Sales                 1          2
# 2               Research & Development                 8          1
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
# df.sort_values(['Age'], ascending=[0])

df.sort_values(['Age'])
# Out:
#                 Age Attrition     BusinessTravel  DailyRate  \
# EmployeeNumber
# 1839             18        No         Non-Travel       1431
# 614              18       Yes  Travel_Frequently       1306
# 1368             18        No         Non-Travel       1124
# 411              18        No      Travel_Rarely        812
# 405              18       Yes      Travel_Rarely        230
# ...             ...       ...                ...        ...
# 732              60        No      Travel_Rarely       1179
# 573              60        No  Travel_Frequently       1499
# 549              60        No      Travel_Rarely        422
# 1233             60        No      Travel_Rarely        696
# 1697             60        No      Travel_Rarely        370
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1839            Research & Development                14          3
# 614                              Sales                 5          3
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:
df.sample()
# Out:
#                 Age Attrition BusinessTravel  DailyRate  \
# EmployeeNumber
# 1501             55        No  Travel_Rarely       1229
#
#                             Department  DistanceFromHome  Education  \
# EmployeeNumber
# 1501            Research & Development                 4          4
#
#                EducationField  EmployeeCount  EnvironmentSatisfaction  ...  \
# EmployeeNumber                                                         ...
# 1501            Life Sciences              1                        4  ...
#
#                RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# EmployeeNumber
# 1501                                  2             80                 0
#
#                 TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# EmployeeNumber
# 1501                            4                     2                3
#
#                YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# EmployeeNumber
# ...

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:
df['Job_Title'] == 'CEO'
# Out:
# EmployeeNumber
# 1       False
# 2       False
# 4       False
# 5       False
# 7       False
#         ...
# 2061    False
# 2062    False
# 2064    False
# 2065    False
# 2068    False
# Name: Job_Title, Length: 1470, dtype: bool

# %%
# A:
df.loc[df['Job_Title'] == 'CEO']
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, Job_Title, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# #### 4.B Group By Age

# %%
age_dist = df.groupby(['Age']).size()
age_dist
# Out:
# Age
# 18     8
# 19     9
# 20    11
# 21    13
# 22    16
# 23    14
# 24    26
# 25    26
# 26    39
# 27    48
# 28    48
# 29    68
# 30    60
# 31    69
# 32    61
# 33    58
# 34    77
# 35    78
# 36    69
# 37    50
# 38    58
# 39    42
# 40    57
# 41    40
# 42    46
# 43    32
# 44    33
# 45    41
# 46    33
# 47    24
# 48    19
# 49    24
# 50    30
# 51    19
# 52    18
# 53    19
# 54    18
# 55    22
# 56    14
# 57     4
# 58    14
# 59    10
# 60     5
# dtype: int64

# %% [markdown]
# # 5. Visualization
#
#
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:
num_bins = 50
n, bins, patches = plt.hist(df.Age, num_bins, facecolor='blue', alpha=0.5)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
plt.boxplot(df.Age)
plt.yscale('linear')
plt.grid(b=True, which='major', color='b', linestyle='-')
plt.grid(b=True, which='minor', color='r', linestyle='--')
plt.show()

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
plt.scatter(df.Age, df.YearsAtCompany)
plt.show()

# %% [markdown]
# #### 5.D Plot Histogram of store_name

# %%
# A:
num_bins = 3
n, bins, patches = plt.hist(df.Department, num_bins, facecolor='blue', alpha=0.5)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A: To print Statistical Summary of Age
from scipy import stats
print('statistical summary of observations =',stats.describe(df.Age))
# Out:
# statistical summary of observations = DescribeResult(nobs=1470, minmax=(18, 60), mean=36.923809523809524, variance=83.45504878602223, skewness=0.41286446154785084, kurtosis=-0.40685066033188644)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
