# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.1.3
#
# ## Data
#
# The Philippine Statistics Authority (PSA) spearheads the conduct of the Family Income and Expenditure Survey (FIES) nationwide. The survey, which is undertaken every three (3) years, is aimed at providing data on family income and expenditure, including, among others, levels of consumption by item of expenditure, sources of income in cash, and related information affecting income and expenditure levels and patterns in the Philippines.
#
# You can download the data from [here](https://www.kaggle.com/grosvenpaul/family-income-and-expenditure).
#
# The purpose of today's lab is to use simulation to visualize the sampling distribution for the sample mean. The Central Limit Theorem (CLT) tells us that as our sample size gets larger, the sampling distribution of the sample mean converges to a normal distribution. Therefore, when we have a large sample size, we can say that the sampling distribution for the sample mean is approximately normal, regardless of the distribution from which we are sampling.
#
# Let's start by taking a look at the data, **`Total Household Income`** will serve as a "population" for the purposes of this lab.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# house_hold = pd.read_csv("../../DATA/Family Income and Expenditure.csv")
house_hold = pd.read_csv('Family_Income_and_Expenditure.csv')

# %%
# Head... view first 5 rows of the dataset
house_hold.head().T
# Out:
#                                                                                                0  \
# Total Household Income                                                                    480332
# Region                                                                                       CAR
# Total Food Expenditure                                                                    117848
# Main Source of Income                                                              Wage/Salaries
# Agricultural Household indicator                                                               0
# Bread and Cereals Expenditure                                                              42140
# Total Rice Expenditure                                                                     38300
# Meat Expenditure                                                                           24676
# Total Fish and  marine products Expenditure                                                16806
# Fruit Expenditure                                                                           3325
# Vegetables Expenditure                                                                     13460
# Restaurant and hotels Expenditure                                                           3000
# Alcoholic Beverages Expenditure                                                                0
# Tobacco Expenditure                                                                            0
# Clothing, Footwear and Other Wear Expenditure                                               4607
# Housing and water Expenditure                                                              63636
# Imputed House Rental Value                                                                 30000
# Medical Care Expenditure                                                                    3457
# Transportation Expenditure                                                                  4776
# Communication Expenditure                                                                   2880
# Education Expenditure                                                                      36200
# Miscellaneous Goods and Services Expenditure                                               34056
# Special Occasions Expenditure                                                               7200
# Crop Farming and Gardening expenses                                                        19370
# Total Income from Entrepreneurial Acitivites                                               44370
# Household Head Sex                                                                        Female
# Household Head Age                                                                            49
# Household Head Marital Status                                                             Single
# Household Head Highest Grade Completed          Teacher Training and Education Sciences Programs
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                      General elementary education teaching professi...
# Household Head Class of Worker                      Worked for government/government corporation
# Type of Household                                                                Extended Family
# Total Number of Family members                                                                 4
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              1
# Total number of family members employed                                                        1
# Type of Building/House                                                              Single house
# Type of Roof                                   Strong material(galvanized,iron,al,tile,concre...
# Type of Walls                                                                             Strong
# House Floor Area                                                                              80
# House Age                                                                                     75
# Number of bedrooms                                                                             3
# Tenure Status                                      Own or owner-like possession of house and lot
# Toilet Facilities                              Water-sealed, sewer septic tank, used exclusiv...
# Electricity                                                                                    1
# Main Source of Water Supply                              Own use, faucet, community water system
# Number of Television                                                                           1
# Number of CD/VCD/DVD                                                                           1
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 1
# Number of Washing Machine                                                                      1
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       2
# Number of Personal Computer                                                                    1
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  1
#
#                                                                                                1  \
# Total Household Income                                                                    198235
# Region                                                                                       CAR
# Total Food Expenditure                                                                     67766
# Main Source of Income                                                              Wage/Salaries
# Agricultural Household indicator                                                               0
# Bread and Cereals Expenditure                                                              17329
# Total Rice Expenditure                                                                     13008
# Meat Expenditure                                                                           17434
# Total Fish and  marine products Expenditure                                                11073
# Fruit Expenditure                                                                           2035
# Vegetables Expenditure                                                                      7833
# Restaurant and hotels Expenditure                                                           2360
# Alcoholic Beverages Expenditure                                                              960
# Tobacco Expenditure                                                                         2132
# Clothing, Footwear and Other Wear Expenditure                                               8230
# Housing and water Expenditure                                                              41370
# Imputed House Rental Value                                                                 27000
# Medical Care Expenditure                                                                    3520
# Transportation Expenditure                                                                 12900
# Communication Expenditure                                                                   5700
# Education Expenditure                                                                      29300
# Miscellaneous Goods and Services Expenditure                                                9150
# Special Occasions Expenditure                                                               1500
# Crop Farming and Gardening expenses                                                            0
# Total Income from Entrepreneurial Acitivites                                                   0
# Household Head Sex                                                                          Male
# Household Head Age                                                                            40
# Household Head Marital Status                                                            Married
# Household Head Highest Grade Completed                               Transport Services Programs
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                                                   Transport conductors
# Household Head Class of Worker                                  Worked for private establishment
# Type of Household                                                                  Single Family
# Total Number of Family members                                                                 3
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              1
# Total number of family members employed                                                        2
# Type of Building/House                                                              Single house
# Type of Roof                                   Strong material(galvanized,iron,al,tile,concre...
# Type of Walls                                                                             Strong
# House Floor Area                                                                              42
# House Age                                                                                     15
# Number of bedrooms                                                                             2
# Tenure Status                                      Own or owner-like possession of house and lot
# Toilet Facilities                              Water-sealed, sewer septic tank, used exclusiv...
# Electricity                                                                                    1
# Main Source of Water Supply                              Own use, faucet, community water system
# Number of Television                                                                           1
# Number of CD/VCD/DVD                                                                           1
# Number of Component/Stereo set                                                                 1
# Number of Refrigerator/Freezer                                                                 0
# Number of Washing Machine                                                                      1
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       3
# Number of Personal Computer                                                                    1
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  2
#
#                                                                                                2  \
# Total Household Income                                                                     82785
# Region                                                                                       CAR
# Total Food Expenditure                                                                     61609
# Main Source of Income                                                              Wage/Salaries
# Agricultural Household indicator                                                               1
# Bread and Cereals Expenditure                                                              34182
# Total Rice Expenditure                                                                     32001
# Meat Expenditure                                                                            7783
# Total Fish and  marine products Expenditure                                                 2590
# Fruit Expenditure                                                                           1730
# Vegetables Expenditure                                                                      3795
# Restaurant and hotels Expenditure                                                           4545
# Alcoholic Beverages Expenditure                                                              270
# Tobacco Expenditure                                                                         4525
# Clothing, Footwear and Other Wear Expenditure                                               2735
# Housing and water Expenditure                                                              14340
# Imputed House Rental Value                                                                  7200
# Medical Care Expenditure                                                                      70
# Transportation Expenditure                                                                   324
# Communication Expenditure                                                                    420
# Education Expenditure                                                                        425
# Miscellaneous Goods and Services Expenditure                                                6450
# Special Occasions Expenditure                                                                500
# Crop Farming and Gardening expenses                                                            0
# Total Income from Entrepreneurial Acitivites                                                   0
# Household Head Sex                                                                          Male
# Household Head Age                                                                            39
# Household Head Marital Status                                                            Married
# Household Head Highest Grade Completed                                                   Grade 3
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                                                 Farmhands and laborers
# Household Head Class of Worker                                  Worked for private establishment
# Type of Household                                                                  Single Family
# Total Number of Family members                                                                 6
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              4
# Total number of family members employed                                                        3
# Type of Building/House                                                              Single house
# Type of Roof                                                  Light material (cogon,nipa,anahaw)
# Type of Walls                                                                              Light
# House Floor Area                                                                              35
# House Age                                                                                     12
# Number of bedrooms                                                                             1
# Tenure Status                                      Own or owner-like possession of house and lot
# Toilet Facilities                              Water-sealed, sewer septic tank, shared with o...
# Electricity                                                                                    0
# Main Source of Water Supply                               Shared, faucet, community water system
# Number of Television                                                                           0
# Number of CD/VCD/DVD                                                                           0
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 0
# Number of Washing Machine                                                                      0
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       0
# Number of Personal Computer                                                                    0
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  0
#
#                                                                                               3  \
# Total Household Income                                                                   107589
# Region                                                                                      CAR
# Total Food Expenditure                                                                    78189
# Main Source of Income                                                             Wage/Salaries
# Agricultural Household indicator                                                              0
# Bread and Cereals Expenditure                                                             34030
# Total Rice Expenditure                                                                    28659
# Meat Expenditure                                                                          10914
# Total Fish and  marine products Expenditure                                               10812
# Fruit Expenditure                                                                           690
# Vegetables Expenditure                                                                     7887
# Restaurant and hotels Expenditure                                                          6280
# Alcoholic Beverages Expenditure                                                             480
# Tobacco Expenditure                                                                           0
# Clothing, Footwear and Other Wear Expenditure                                              1390
# Housing and water Expenditure                                                             16638
# Imputed House Rental Value                                                                 6600
# Medical Care Expenditure                                                                     60
# Transportation Expenditure                                                                 6840
# Communication Expenditure                                                                   660
# Education Expenditure                                                                       300
# Miscellaneous Goods and Services Expenditure                                               3762
# Special Occasions Expenditure                                                               500
# Crop Farming and Gardening expenses                                                       15580
# Total Income from Entrepreneurial Acitivites                                              15580
# Household Head Sex                                                                         Male
# Household Head Age                                                                           52
# Household Head Marital Status                                                           Married
# Household Head Highest Grade Completed                                      Elementary Graduate
# Household Head Job or Business Indicator                                      With Job/Business
# Household Head Occupation                                                          Rice farmers
# Household Head Class of Worker                 Employer in own family-operated farm or business
# Type of Household                                                                 Single Family
# Total Number of Family members                                                                3
# Members with age less than 5 year old                                                         0
# Members with age 5 - 17 years old                                                             3
# Total number of family members employed                                                       2
# Type of Building/House                                                             Single house
# Type of Roof                                                 Light material (cogon,nipa,anahaw)
# Type of Walls                                                                             Light
# House Floor Area                                                                             30
# House Age                                                                                    15
# Number of bedrooms                                                                            1
# Tenure Status                                     Own or owner-like possession of house and lot
# Toilet Facilities                                                                    Closed pit
# Electricity                                                                                   1
# Main Source of Water Supply                             Own use, faucet, community water system
# Number of Television                                                                          1
# Number of CD/VCD/DVD                                                                          0
# Number of Component/Stereo set                                                                0
# Number of Refrigerator/Freezer                                                                0
# Number of Washing Machine                                                                     0
# Number of Airconditioner                                                                      0
# Number of Car, Jeep, Van                                                                      0
# Number of Landline/wireless telephones                                                        0
# Number of Cellular phone                                                                      1
# Number of Personal Computer                                                                   0
# Number of Stove with Oven/Gas Range                                                           0
# Number of Motorized Banca                                                                     0
# Number of Motorcycle/Tricycle                                                                 0
#
#                                                                                                4
# Total Household Income                                                                    189322
# Region                                                                                       CAR
# Total Food Expenditure                                                                     94625
# Main Source of Income                                                              Wage/Salaries
# Agricultural Household indicator                                                               0
# Bread and Cereals Expenditure                                                              34820
# Total Rice Expenditure                                                                     30167
# Meat Expenditure                                                                           18391
# Total Fish and  marine products Expenditure                                                11309
# Fruit Expenditure                                                                           1395
# Vegetables Expenditure                                                                     11260
# Restaurant and hotels Expenditure                                                           6400
# Alcoholic Beverages Expenditure                                                             1040
# Tobacco Expenditure                                                                            0
# Clothing, Footwear and Other Wear Expenditure                                               4620
# Housing and water Expenditure                                                              31122
# Imputed House Rental Value                                                                 16800
# Medical Care Expenditure                                                                     140
# Transportation Expenditure                                                                  6996
# Communication Expenditure                                                                   2100
# Education Expenditure                                                                          0
# Miscellaneous Goods and Services Expenditure                                                8472
# Special Occasions Expenditure                                                               1000
# Crop Farming and Gardening expenses                                                        18887
# Total Income from Entrepreneurial Acitivites                                               75687
# Household Head Sex                                                                          Male
# Household Head Age                                                                            65
# Household Head Marital Status                                                            Married
# Household Head Highest Grade Completed                                       Elementary Graduate
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                      General managers/managing proprietors in trans...
# Household Head Class of Worker                                 Self-employed wihout any employee
# Type of Household                                                                  Single Family
# Total Number of Family members                                                                 4
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              0
# Total number of family members employed                                                        2
# Type of Building/House                                                              Single house
# Type of Roof                                                  Light material (cogon,nipa,anahaw)
# Type of Walls                                                                       Quite Strong
# House Floor Area                                                                              54
# House Age                                                                                     16
# Number of bedrooms                                                                             3
# Tenure Status                                      Own or owner-like possession of house and lot
# Toilet Facilities                              Water-sealed, sewer septic tank, used exclusiv...
# Electricity                                                                                    1
# Main Source of Water Supply                              Own use, faucet, community water system
# Number of Television                                                                           1
# Number of CD/VCD/DVD                                                                           0
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 1
# Number of Washing Machine                                                                      0
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       3
# Number of Personal Computer                                                                    0
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  1

# %%
# Tail... view last 5 rows of the dataset
house_hold.tail().T
# Out:
#                                                                                        41539  \
# Total Household Income                                                                119773
# Region                                                                    XII - SOCCSKSARGEN
# Total Food Expenditure                                                                 44875
# Main Source of Income                                             Enterpreneurial Activities
# Agricultural Household indicator                                                           1
# Bread and Cereals Expenditure                                                          23675
# Total Rice Expenditure                                                                 21542
# Meat Expenditure                                                                        1476
# Total Fish and  marine products Expenditure                                             6120
# Fruit Expenditure                                                                       1632
# Vegetables Expenditure                                                                  3882
# Restaurant and hotels Expenditure                                                       1805
# Alcoholic Beverages Expenditure                                                            0
# Tobacco Expenditure                                                                      133
# Clothing, Footwear and Other Wear Expenditure                                           1395
# Housing and water Expenditure                                                          18372
# Imputed House Rental Value                                                             12000
# Medical Care Expenditure                                                                 294
# Transportation Expenditure                                                              2124
# Communication Expenditure                                                                600
# Education Expenditure                                                                     50
# Miscellaneous Goods and Services Expenditure                                            3978
# Special Occasions Expenditure                                                           2500
# Crop Farming and Gardening expenses                                                    94120
# Total Income from Entrepreneurial Acitivites                                           94120
# Household Head Sex                                                                      Male
# Household Head Age                                                                        42
# Household Head Marital Status                                                        Married
# Household Head Highest Grade Completed                                   Elementary Graduate
# Household Head Job or Business Indicator                                   With Job/Business
# Household Head Occupation                                                       Rice farmers
# Household Head Class of Worker                             Self-employed wihout any employee
# Type of Household                                                            Extended Family
# Total Number of Family members                                                             6
# Members with age less than 5 year old                                                      2
# Members with age 5 - 17 years old                                                          0
# Total number of family members employed                                                    0
# Type of Building/House                                                          Single house
# Type of Roof                                        Mixed but predominantly strong materials
# Type of Walls                                                                         Strong
# House Floor Area                                                                          30
# House Age                                                                                 14
# Number of bedrooms                                                                         1
# Tenure Status                                  Own or owner-like possession of house and lot
# Toilet Facilities                                                                   Open pit
# Electricity                                                                                1
# Main Source of Water Supply                                   Own use, tubed/piped deep well
# Number of Television                                                                       1
# Number of CD/VCD/DVD                                                                       0
# Number of Component/Stereo set                                                             0
# Number of Refrigerator/Freezer                                                             0
# Number of Washing Machine                                                                  0
# Number of Airconditioner                                                                   0
# Number of Car, Jeep, Van                                                                   0
# Number of Landline/wireless telephones                                                     0
# Number of Cellular phone                                                                   1
# Number of Personal Computer                                                                0
# Number of Stove with Oven/Gas Range                                                        0
# Number of Motorized Banca                                                                  0
# Number of Motorcycle/Tricycle                                                              0
#
#                                                                                            41540  \
# Total Household Income                                                                    137320
# Region                                                                        XII - SOCCSKSARGEN
# Total Food Expenditure                                                                     31157
# Main Source of Income                                                 Enterpreneurial Activities
# Agricultural Household indicator                                                               1
# Bread and Cereals Expenditure                                                               2691
# Total Rice Expenditure                                                                      1273
# Meat Expenditure                                                                            1886
# Total Fish and  marine products Expenditure                                                 4386
# Fruit Expenditure                                                                           1840
# Vegetables Expenditure                                                                      3110
# Restaurant and hotels Expenditure                                                           9090
# Alcoholic Beverages Expenditure                                                                0
# Tobacco Expenditure                                                                          300
# Clothing, Footwear and Other Wear Expenditure                                               3136
# Housing and water Expenditure                                                              17640
# Imputed House Rental Value                                                                 10800
# Medical Care Expenditure                                                                     890
# Transportation Expenditure                                                                  2568
# Communication Expenditure                                                                   1560
# Education Expenditure                                                                       1550
# Miscellaneous Goods and Services Expenditure                                                6090
# Special Occasions Expenditure                                                               1500
# Crop Farming and Gardening expenses                                                        78270
# Total Income from Entrepreneurial Acitivites                                               78270
# Household Head Sex                                                                          Male
# Household Head Age                                                                            49
# Household Head Marital Status                                                            Married
# Household Head Highest Grade Completed                                       Elementary Graduate
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                                                           Rice farmers
# Household Head Class of Worker                                 Self-employed wihout any employee
# Type of Household                                                                  Single Family
# Total Number of Family members                                                                 6
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              3
# Total number of family members employed                                                        0
# Type of Building/House                                                              Single house
# Type of Roof                                   Strong material(galvanized,iron,al,tile,concre...
# Type of Walls                                                                             Strong
# House Floor Area                                                                              40
# House Age                                                                                      6
# Number of bedrooms                                                                             2
# Tenure Status                                      Own or owner-like possession of house and lot
# Toilet Facilities                                                                       Open pit
# Electricity                                                                                    1
# Main Source of Water Supply                                       Own use, tubed/piped deep well
# Number of Television                                                                           1
# Number of CD/VCD/DVD                                                                           1
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 0
# Number of Washing Machine                                                                      0
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       3
# Number of Personal Computer                                                                    0
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  0
#
#                                                                                         41541  \
# Total Household Income                                                                 133171
# Region                                                                     XII - SOCCSKSARGEN
# Total Food Expenditure                                                                  45882
# Main Source of Income                                              Enterpreneurial Activities
# Agricultural Household indicator                                                            2
# Bread and Cereals Expenditure                                                           28646
# Total Rice Expenditure                                                                  27339
# Meat Expenditure                                                                          480
# Total Fish and  marine products Expenditure                                              4796
# Fruit Expenditure                                                                        1232
# Vegetables Expenditure                                                                   3025
# Restaurant and hotels Expenditure                                                        3330
# Alcoholic Beverages Expenditure                                                             0
# Tobacco Expenditure                                                                         0
# Clothing, Footwear and Other Wear Expenditure                                            2460
# Housing and water Expenditure                                                            9240
# Imputed House Rental Value                                                               4800
# Medical Care Expenditure                                                                  540
# Transportation Expenditure                                                               2040
# Communication Expenditure                                                                1080
# Education Expenditure                                                                       0
# Miscellaneous Goods and Services Expenditure                                             3570
# Special Occasions Expenditure                                                             500
# Crop Farming and Gardening expenses                                                     54965
# Total Income from Entrepreneurial Acitivites                                            98545
# Household Head Sex                                                                       Male
# Household Head Age                                                                         56
# Household Head Marital Status                                                         Married
# Household Head Highest Grade Completed                                                Grade 1
# Household Head Job or Business Indicator                                    With Job/Business
# Household Head Occupation                                                        Rice farmers
# Household Head Class of Worker                              Self-employed wihout any employee
# Type of Household                                                               Single Family
# Total Number of Family members                                                              4
# Members with age less than 5 year old                                                       0
# Members with age 5 - 17 years old                                                           0
# Total number of family members employed                                                     1
# Type of Building/House                                                           Single house
# Type of Roof                                               Light material (cogon,nipa,anahaw)
# Type of Walls                                                                          Strong
# House Floor Area                                                                           35
# House Age                                                                                  20
# Number of bedrooms                                                                          1
# Tenure Status                                  Own house, rent-free lot with consent of owner
# Toilet Facilities                                                                    Open pit
# Electricity                                                                                 1
# Main Source of Water Supply                                    Own use, tubed/piped deep well
# Number of Television                                                                        0
# Number of CD/VCD/DVD                                                                        0
# Number of Component/Stereo set                                                              0
# Number of Refrigerator/Freezer                                                              0
# Number of Washing Machine                                                                   0
# Number of Airconditioner                                                                    0
# Number of Car, Jeep, Van                                                                    0
# Number of Landline/wireless telephones                                                      0
# Number of Cellular phone                                                                    1
# Number of Personal Computer                                                                 0
# Number of Stove with Oven/Gas Range                                                         0
# Number of Motorized Banca                                                                   0
# Number of Motorcycle/Tricycle                                                               0
#
#                                                                                            41542  \
# Total Household Income                                                                    129500
# Region                                                                        XII - SOCCSKSARGEN
# Total Food Expenditure                                                                     81416
# Main Source of Income                                                 Enterpreneurial Activities
# Agricultural Household indicator                                                               1
# Bread and Cereals Expenditure                                                              29996
# Total Rice Expenditure                                                                     26655
# Meat Expenditure                                                                            2359
# Total Fish and  marine products Expenditure                                                17730
# Fruit Expenditure                                                                           2923
# Vegetables Expenditure                                                                      7951
# Restaurant and hotels Expenditure                                                          13660
# Alcoholic Beverages Expenditure                                                                0
# Tobacco Expenditure                                                                          630
# Clothing, Footwear and Other Wear Expenditure                                               3755
# Housing and water Expenditure                                                              12438
# Imputed House Rental Value                                                                  7200
# Medical Care Expenditure                                                                     314
# Transportation Expenditure                                                                  2412
# Communication Expenditure                                                                   1020
# Education Expenditure                                                                       5295
# Miscellaneous Goods and Services Expenditure                                                5760
# Special Occasions Expenditure                                                               1000
# Crop Farming and Gardening expenses                                                        95785
# Total Income from Entrepreneurial Acitivites                                              107435
# Household Head Sex                                                                          Male
# Household Head Age                                                                            34
# Household Head Marital Status                                                            Widowed
# Household Head Highest Grade Completed                                    First Year High School
# Household Head Job or Business Indicator                                       With Job/Business
# Household Head Occupation                                                           Rice farmers
# Household Head Class of Worker                                 Self-employed wihout any employee
# Type of Household                                                                Extended Family
# Total Number of Family members                                                                 9
# Members with age less than 5 year old                                                          0
# Members with age 5 - 17 years old                                                              3
# Total number of family members employed                                                        0
# Type of Building/House                                                              Single house
# Type of Roof                                   Strong material(galvanized,iron,al,tile,concre...
# Type of Walls                                                                             Strong
# House Floor Area                                                                              25
# House Age                                                                                     11
# Number of bedrooms                                                                             1
# Tenure Status                                  Own house, rent-free lot without consent of owner
# Toilet Facilities                                                                       Open pit
# Electricity                                                                                    1
# Main Source of Water Supply                                                             Dug well
# Number of Television                                                                           0
# Number of CD/VCD/DVD                                                                           0
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 0
# Number of Washing Machine                                                                      0
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       2
# Number of Personal Computer                                                                    0
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  0
#
#                                                                                            41543
# Total Household Income                                                                    128598
# Region                                                                        XII - SOCCSKSARGEN
# Total Food Expenditure                                                                     78195
# Main Source of Income                                                 Enterpreneurial Activities
# Agricultural Household indicator                                                               1
# Bread and Cereals Expenditure                                                              43485
# Total Rice Expenditure                                                                     41205
# Meat Expenditure                                                                            1985
# Total Fish and  marine products Expenditure                                                 7735
# Fruit Expenditure                                                                           2062
# Vegetables Expenditure                                                                      7114
# Restaurant and hotels Expenditure                                                           5750
# Alcoholic Beverages Expenditure                                                                0
# Tobacco Expenditure                                                                          120
# Clothing, Footwear and Other Wear Expenditure                                               2320
# Housing and water Expenditure                                                              11316
# Imputed House Rental Value                                                                  6000
# Medical Care Expenditure                                                                     330
# Transportation Expenditure                                                                  1560
# Communication Expenditure                                                                    960
# Education Expenditure                                                                         80
# Miscellaneous Goods and Services Expenditure                                                6060
# Special Occasions Expenditure                                                               2500
# Crop Farming and Gardening expenses                                                        84247
# Total Income from Entrepreneurial Acitivites                                              105547
# Household Head Sex                                                                          Male
# Household Head Age                                                                            86
# Household Head Marital Status                                                            Married
# Household Head Highest Grade Completed                                        No Grade Completed
# Household Head Job or Business Indicator                                         No Job/Business
# Household Head Occupation                                                                    NaN
# Household Head Class of Worker                                                               NaN
# Type of Household                                                                  Single Family
# Total Number of Family members                                                                 8
# Members with age less than 5 year old                                                          1
# Members with age 5 - 17 years old                                                              1
# Total number of family members employed                                                        0
# Type of Building/House                                                              Single house
# Type of Roof                                            Mixed but predominantly strong materials
# Type of Walls                                                                             Strong
# House Floor Area                                                                              28
# House Age                                                                                     10
# Number of bedrooms                                                                             1
# Tenure Status                                  Own house, rent-free lot without consent of owner
# Toilet Facilities                                                                       Open pit
# Electricity                                                                                    1
# Main Source of Water Supply                                                             Dug well
# Number of Television                                                                           0
# Number of CD/VCD/DVD                                                                           0
# Number of Component/Stereo set                                                                 0
# Number of Refrigerator/Freezer                                                                 0
# Number of Washing Machine                                                                      0
# Number of Airconditioner                                                                       0
# Number of Car, Jeep, Van                                                                       0
# Number of Landline/wireless telephones                                                         0
# Number of Cellular phone                                                                       1
# Number of Personal Computer                                                                    0
# Number of Stove with Oven/Gas Range                                                            0
# Number of Motorized Banca                                                                      0
# Number of Motorcycle/Tricycle                                                                  0

# %%
# Shape... Shape = (ROWS, COLUMNS)
print(f'(ROWS, COLUMNS)=')
house_hold.shape
# Out:
# (41544, 60)

# %%
# Data Types
house_hold.dtypes
# Out:
# Total Household Income                            int64
# Region                                           object
# Total Food Expenditure                            int64
# Main Source of Income                            object
# Agricultural Household indicator                  int64
# Bread and Cereals Expenditure                     int64
# Total Rice Expenditure                            int64
# Meat Expenditure                                  int64
# Total Fish and  marine products Expenditure       int64
# Fruit Expenditure                                 int64
# Vegetables Expenditure                            int64
# Restaurant and hotels Expenditure                 int64
# Alcoholic Beverages Expenditure                   int64
# Tobacco Expenditure                               int64
# Clothing, Footwear and Other Wear Expenditure     int64
# Housing and water Expenditure                     int64
# Imputed House Rental Value                        int64
# Medical Care Expenditure                          int64
# Transportation Expenditure                        int64
# Communication Expenditure                         int64
# Education Expenditure                             int64
# Miscellaneous Goods and Services Expenditure      int64
# Special Occasions Expenditure                     int64
# Crop Farming and Gardening expenses               int64
# Total Income from Entrepreneurial Acitivites      int64
# Household Head Sex                               object
# Household Head Age                                int64
# Household Head Marital Status                    object
# Household Head Highest Grade Completed           object
# Household Head Job or Business Indicator         object
# Household Head Occupation                        object
# Household Head Class of Worker                   object
# Type of Household                                object
# Total Number of Family members                    int64
# Members with age less than 5 year old             int64
# Members with age 5 - 17 years old                 int64
# Total number of family members employed           int64
# Type of Building/House                           object
# Type of Roof                                     object
# Type of Walls                                    object
# House Floor Area                                  int64
# House Age                                         int64
# Number of bedrooms                                int64
# Tenure Status                                    object
# Toilet Facilities                                object
# Electricity                                       int64
# Main Source of Water Supply                      object
# Number of Television                              int64
# Number of CD/VCD/DVD                              int64
# Number of Component/Stereo set                    int64
# Number of Refrigerator/Freezer                    int64
# Number of Washing Machine                         int64
# Number of Airconditioner                          int64
# Number of Car, Jeep, Van                          int64
# Number of Landline/wireless telephones            int64
# Number of Cellular phone                          int64
# Number of Personal Computer                       int64
# Number of Stove with Oven/Gas Range               int64
# Number of Motorized Banca                         int64
# Number of Motorcycle/Tricycle                     int64
# dtype: object

# %% [markdown]
# #### Surveying the populations
#
# ##### 1. Create a histogram of `Total Household Income`.

# %%
# ANSWER

fig, ax = plt.subplots(figsize = (16,8))
sns.distplot(house_hold['Total Household Income']);

# %% [markdown]
# ##### 2. How would you describe the shape of this population?

# %% [markdown]
# **ANSWER**
#
# > This distribution is called skewed right if, as in the histogram above, the right tail (larger values) is much longer than the left tail (small values).

# %% [markdown]
# ##### 2. What is the mean income of this population?

# %%
# ANSWER
mean_income = house_hold['Total Household Income'].mean()
print('Mean Income:', mean_income)
# Out:
# Mean Income: 247555.58480165608

# %% [markdown]
# ##### 3. What sampling statistic/point estimate would you use to estimate the mean of this population if you were given a random sample from the population?

# %%
# ANSWER

# %% [markdown]
# **ANSWER**
#
# > We use the sample mean X as our estimate of the population mean μ.

# %% [markdown]
# #### Simulated sampling (sample means)

# %% [markdown]
# Now, we'd like to get an idea of what happens when we take multiple random samples of size 5.
#
# Take 10 sample (size=5) from the entire population. Calculate means for each sample. Now make a histogram of all the sample means.
#
# - Describe the shape of the histogram.
# - What is the center of the distribution of sample means?

# %% [markdown]
# ##### 4. Simulation with `sample_size=5`

# %% [markdown]
# Take 10 samples, but with a sample size of 5.

# %%
def calculate_sample_mean(df, column_name, N=10, sample_size=5):
    '''
    df: DataFrame
    column_name: String, column_name
    N: Number of samples
    sample_size: Size of sample for each sample
    '''
    sample_mean_list = []

    for i in range(N):
        df_sample = df.sample(n=sample_size)
        sample_mean = df_sample[column_name].mean()
        sample_mean_list.append(sample_mean)
    
    return sample_mean_list

# %%
def visual_sample_mean(population_mean, sample_mean_list):
    '''
    population_mean: mean of entire population
    sample_mean_list: list of sample mean
    '''
    
    sample_mean = np.mean(sample_mean_list)
    
    fig, ax = plt.subplots(figsize = (16,8))
    ax = sns.distplot(sample_mean_list);
    
    # plot a vertical line for population mean and sample mean
    ax.axvline(population_mean, color='black', linestyle='solid', lw=1)
    ax.axvline(sample_mean, color='red', linestyle='dashed', lw=1)
    
    plt.xlabel('Mean of Samples')
    plt.ylabel('Frequency')

    plt.show()

# %%
sample_mean_list = calculate_sample_mean(house_hold
                                         , 'Total Household Income'
                                         , N=10
                                         , sample_size=5)

# %% [markdown]
# ###### 4.A Make a histogram of all the sample means

# %%
# ANSWER
visual_sample_mean(mean_income, sample_mean_list)

# %% [markdown]
# ###### 4.B Describe the shape of the histogram.

# %% [markdown]
# **ANSWER:**
#
# > This distribution is called skewed right if, as in the histogram above, the right tail (larger values) is much longer than the left tail (small values).

# %% [markdown]
# ##### 7. Simulation with `sample_size=15`

# %% [markdown]
# let's try taking another 1000 samples, but with a sample size of 15

# %%
# ANSWER
sample_mean_list = calculate_sample_mean(house_hold
                                         , 'Total Household Income'
                                         , N=1000
                                         , sample_size=15)

visual_sample_mean(mean_income, sample_mean_list)

# %% [markdown]
# ##### 8. Simulation with `sample_size=50`

# %% [markdown]
# Let's try taking another 1000 samples, but with a sample size of 50

# %%
# ANSWER
sample_mean_list = calculate_sample_mean(house_hold
                                         , 'Total Household Income'
                                         , N=1000
                                         , sample_size=50)

visual_sample_mean(mean_income, sample_mean_list)

# %% [markdown]
# ###### 8.A Describe the shape of the histogram of sample means (using sample size of 50)

# %% [markdown]
# **ANSWER:**
#
# > This distribution is almost symmetric.

# %% [markdown]
# ###### 8.B What is mean of the distribution of sample means?

# %%
# ANSWER
np.mean(sample_mean_list)
# Out:
# 247349.06984000004

# %% [markdown]
# **ANSWER:**
#
# > If repeated random samples of a given size n are taken from a population of values for a quantitative variable, where the population mean is μ (mu) and the population standard deviation is σ (sigma) then the mean of all sample means (x-bars) is population mean μ (mu).

# %% [markdown]
# ###### 8.C As the sample size grew, did your results confirm the CLT?

# %% [markdown]
# **ANSWER:**
#
# Yes.
#
# > To summarize, the distribution of sample means will be approximately normal as long as the sample size is large enough.
#
# > We will depend on the Central Limit Theorem again and again in order to do normal probability calculations when we use sample means to draw conclusions about a population mean. We now know that we can do this even if the population distribution is not normal.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
